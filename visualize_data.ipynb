# %%
import plotly.express as px
import pandas as pd

# %%
df = pd.read_csv("dataset.csv", infer_datetime_format=True, parse_dates=True)
df
# Out:
#         rms  eventID                                        location  \
# 0      0.00   237968                                   Mengen (Bolu)
# 1      0.00   237972                                  Merkez (Sivas)
# 2      0.00   237974                                   Göynük (Bolu)
# 3      0.00   237980                                Sungurlu (Çorum)
# 4      0.00   237985                                   Mengen (Bolu)
# ...     ...      ...                                             ...
# 41222  0.59   542319                               Tosya (Kastamonu)
# 41223  0.38   542320                                Merkez (Bayburt)
# 41224  0.69   542327                            Otlukbeli (Erzincan)
# 41225  0.66   542331  Marmara Denizi - [25.05 km] Silivri (İstanbul)
# 41226  0.93   542332                                  Mudurnu (Bolu)
#
#        latitude  longitude  depth  magnitude  country   province   district  \
# ...

# %%
df.magnitude = df.magnitude.round(1)

# %%
df.date = pd.to_datetime(df.date)

# %%
df = df[df['date'] < '2023-01-01']

# %%
px.histogram(df, x="magnitude", histnorm='probability density')

# %%
df2 = df.groupby(df['date'].map(lambda x: x.year))['eventID'].count().reset_index(name ='Count')
df2.date = df2.date.astype(str)

# %%
px.histogram(df2, x="date", y="Count").update_layout(yaxis_title="Count")

# %%
df['Last Quake'] = df.date.diff().map(lambda x: x.total_seconds()/86400)
# Out:
# C:\Users\murat\AppData\Local\Temp\ipykernel_17532\2771600514.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#         rms  eventID             location  latitude  longitude  depth  \
# 0      0.00   237968        Mengen (Bolu)    41.000     32.000   7.00
# 1      0.00   237972       Merkez (Sivas)    39.740     36.960   1.00
# 2      0.00   237974        Göynük (Bolu)    40.370     30.810   7.00
# 3      0.00   237980     Sungurlu (Çorum)    40.270     34.480   1.00
# 4      0.00   237985        Mengen (Bolu)    41.000     32.000   4.00
# ...     ...      ...                  ...       ...        ...    ...
# 41022  0.17   539849    Erenler (Sakarya)    40.676     30.433   7.06
# 41023  0.13   539854     Kaynaşlı (Düzce)    40.781     31.375   7.02
# 41024  0.14   539857  Refahiye (Erzincan)    39.923     39.061   7.20
# 41025  0.85   539858    Şiran (Gümüşhane)    40.281     39.054   7.00
# 41026  0.26   539861     Akyazı (Sakarya)    40.692     30.590   7.00
#
#        magnitude  country   province  district                    date  \
# ...

# %%
px.histogram(df[df['Last Quake'] < 100], x="Last Quake")
